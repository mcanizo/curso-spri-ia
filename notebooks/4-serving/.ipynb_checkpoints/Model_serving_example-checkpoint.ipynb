# %% [markdown]
# # Model Serving Example

# %% [markdown]
# This notebook contains a toy example to serve a previously logged model. In this example, we will use the already trained Elasticnet models using the wine quality dataset from the UCI repository.

# %% [markdown]
# To serve a model, MLflow provides the command `mlflow models serve -m <artifact-uri> -p <port>`

# %% [markdown]
# We will use the same code as in model registering to get the URI of the best model

# %% [markdown]
# The first step is to import all the required libraries

# %%
# The data set used in this example is from http://archive.ics.uci.edu/ml/datasets/Wine+Quality
# P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.

import os
import warnings
import sys

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from urllib.parse import urlparse
import mlflow
import mlflow.sklearn
import boto3

import logging

logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)

warnings.filterwarnings("ignore")
np.random.seed(40)

# %% [markdown]
# Before registering a model in the MLflow Registry, it is recommended to search for the best model within all the runs and only register that one instead of registering every model.
#
# Once we have performed all the runs in an experiment, we can access the metadata of the experiment using its ID and the method ``search_runs`` provided by MLflow. Check the [documentation](https://www.mlflow.org/docs/latest/python_api/mlflow.html#mlflow.search_runs) for further details.
#
# Go to the MLflow UI and get the experiment ID of your choice.

# %%
# Search all runs in experiment_id
experiment_id = 1  # in this case experiment_id 1 = 'winequality_elasticnet_autolog'
mlflow.search_runs([experiment_id])
# Out:
#                              run_id experiment_id    status  \
# 0  49e52e988cd1436eb48d99104ae0d407             1  FINISHED
# 1  c823e563d0c84de78b140f5fafc676cf             1  FINISHED
# 2  1f5ab48a5cea4118ba8538268c5eb283             1  FINISHED
# 3  dc299a55a6c74c9085fcdd9ca122b9d1             1  FINISHED
# 4  e458c99ffadb4cb9a07b9274c2be7422             1  FINISHED
# 5  d4c7e5ac674643e8bd37d69353109ace             1  FINISHED
#
#                                         artifact_uri  \
# 0  s3://mlflow-bucket/mlflow/1/49e52e988cd1436eb4...
# 1  s3://mlflow-bucket/mlflow/1/c823e563d0c84de78b...
# 2  s3://mlflow-bucket/mlflow/1/1f5ab48a5cea4118ba...
# 3  s3://mlflow-bucket/mlflow/1/dc299a55a6c74c9085...
# 4  s3://mlflow-bucket/mlflow/1/e458c99ffadb4cb9a0...
# 5  s3://mlflow-bucket/mlflow/1/d4c7e5ac674643e8bd...
#
#                         start_time                         end_time  \
# 0 2020-12-08 17:56:40.503000+00:00 2020-12-08 17:56:41.145000+00:00
# 1 2020-12-08 17:56:39.318000+00:00 2020-12-08 17:56:40.241000+00:00
# 2 2020-12-08 17:56:38.275000+00:00 2020-12-08 17:56:39.079000+00:00
# 3 2020-12-08 17:56:37.479000+00:00 2020-12-08 17:56:38.082000+00:00
# 4 2020-12-08 17:56:36.709000+00:00 2020-12-08 17:56:37.353000+00:00
# 5 2020-12-08 17:56:35.542000+00:00 2020-12-08 17:56:36.490000+00:00
#
#    metrics.training_mae  metrics.training_score  metrics.training_rmse  \
# 0              0.621656                0.091266               0.758243
# 1              0.643434                0.040883               0.778979
# 2              0.606329                0.124943               0.744060
# 3              0.603006                0.132211               0.740964
# 4              0.544079                0.248799               0.689394
# 5              0.543255                0.249486               0.689079
#
#    metrics.training_mse  ...  params.positive params.copy_X params.precompute  \
# 0              0.574932  ...            False          True             False
# 1              0.606808  ...            False          True             False
# 2              0.553625  ...            False          True             False
# 3              0.549027  ...            False          True             False
# 4              0.475265  ...            False          True             False
# 5              0.474830  ...            False          True             False
#
#   params.selection tags.mlflow.user tags.mlflow.source.type  \
# 0           cyclic          mcanizo                   LOCAL
# 1           cyclic          mcanizo                   LOCAL
# 2           cyclic          mcanizo                   LOCAL
# 3           cyclic          mcanizo                   LOCAL
# 4           cyclic          mcanizo                   LOCAL
# 5           cyclic          mcanizo                   LOCAL
#
#   tags.estimator_name                      tags.mlflow.log-model.history  \
# 0          ElasticNet  [{"run_id": "49e52e988cd1436eb48d99104ae0d407"...
# 1          ElasticNet  [{"run_id": "c823e563d0c84de78b140f5fafc676cf"...
# 2          ElasticNet  [{"run_id": "1f5ab48a5cea4118ba8538268c5eb283"...
# 3          ElasticNet  [{"run_id": "dc299a55a6c74c9085fcdd9ca122b9d1"...
# 4          ElasticNet  [{"run_id": "e458c99ffadb4cb9a07b9274c2be7422"...
# 5          ElasticNet  [{"run_id": "d4c7e5ac674643e8bd37d69353109ace"...
#
#                              tags.mlflow.source.name  \
# 0  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 1  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 2  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 3  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 4  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 5  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
#
#                                 tags.estimator_class
# 0  sklearn.linear_model._coordinate_descent.Elast...
# 1  sklearn.linear_model._coordinate_descent.Elast...
# 2  sklearn.linear_model._coordinate_descent.Elast...
# 3  sklearn.linear_model._coordinate_descent.Elast...
# 4  sklearn.linear_model._coordinate_descent.Elast...
# 5  sklearn.linear_model._coordinate_descent.Elast...
#
# [6 rows x 29 columns]

# %% [markdown]
# We can make some queries to order the dataframe by column

# %%
mlflow.search_runs([experiment_id], order_by=["metrics.training_mse DESC"])
# Out:
#                              run_id experiment_id    status  \
# 0  c823e563d0c84de78b140f5fafc676cf             1  FINISHED
# 1  49e52e988cd1436eb48d99104ae0d407             1  FINISHED
# 2  1f5ab48a5cea4118ba8538268c5eb283             1  FINISHED
# 3  dc299a55a6c74c9085fcdd9ca122b9d1             1  FINISHED
# 4  e458c99ffadb4cb9a07b9274c2be7422             1  FINISHED
# 5  d4c7e5ac674643e8bd37d69353109ace             1  FINISHED
#
#                                         artifact_uri  \
# 0  s3://mlflow-bucket/mlflow/1/c823e563d0c84de78b...
# 1  s3://mlflow-bucket/mlflow/1/49e52e988cd1436eb4...
# 2  s3://mlflow-bucket/mlflow/1/1f5ab48a5cea4118ba...
# 3  s3://mlflow-bucket/mlflow/1/dc299a55a6c74c9085...
# 4  s3://mlflow-bucket/mlflow/1/e458c99ffadb4cb9a0...
# 5  s3://mlflow-bucket/mlflow/1/d4c7e5ac674643e8bd...
#
#                         start_time                         end_time  \
# 0 2020-12-08 17:56:39.318000+00:00 2020-12-08 17:56:40.241000+00:00
# 1 2020-12-08 17:56:40.503000+00:00 2020-12-08 17:56:41.145000+00:00
# 2 2020-12-08 17:56:38.275000+00:00 2020-12-08 17:56:39.079000+00:00
# 3 2020-12-08 17:56:37.479000+00:00 2020-12-08 17:56:38.082000+00:00
# 4 2020-12-08 17:56:36.709000+00:00 2020-12-08 17:56:37.353000+00:00
# 5 2020-12-08 17:56:35.542000+00:00 2020-12-08 17:56:36.490000+00:00
#
#    metrics.training_mae  metrics.training_score  metrics.training_rmse  \
# 0              0.643434                0.040883               0.778979
# 1              0.621656                0.091266               0.758243
# 2              0.606329                0.124943               0.744060
# 3              0.603006                0.132211               0.740964
# 4              0.544079                0.248799               0.689394
# 5              0.543255                0.249486               0.689079
#
#    metrics.training_mse  ...  params.positive params.copy_X params.precompute  \
# 0              0.606808  ...            False          True             False
# 1              0.574932  ...            False          True             False
# 2              0.553625  ...            False          True             False
# 3              0.549027  ...            False          True             False
# 4              0.475265  ...            False          True             False
# 5              0.474830  ...            False          True             False
#
#   params.selection tags.mlflow.user tags.mlflow.source.type  \
# 0           cyclic          mcanizo                   LOCAL
# 1           cyclic          mcanizo                   LOCAL
# 2           cyclic          mcanizo                   LOCAL
# 3           cyclic          mcanizo                   LOCAL
# 4           cyclic          mcanizo                   LOCAL
# 5           cyclic          mcanizo                   LOCAL
#
#   tags.estimator_name                      tags.mlflow.log-model.history  \
# 0          ElasticNet  [{"run_id": "c823e563d0c84de78b140f5fafc676cf"...
# 1          ElasticNet  [{"run_id": "49e52e988cd1436eb48d99104ae0d407"...
# 2          ElasticNet  [{"run_id": "1f5ab48a5cea4118ba8538268c5eb283"...
# 3          ElasticNet  [{"run_id": "dc299a55a6c74c9085fcdd9ca122b9d1"...
# 4          ElasticNet  [{"run_id": "e458c99ffadb4cb9a07b9274c2be7422"...
# 5          ElasticNet  [{"run_id": "d4c7e5ac674643e8bd37d69353109ace"...
#
#                              tags.mlflow.source.name  \
# 0  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 1  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 2  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 3  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 4  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 5  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
#
#                                 tags.estimator_class
# 0  sklearn.linear_model._coordinate_descent.Elast...
# 1  sklearn.linear_model._coordinate_descent.Elast...
# 2  sklearn.linear_model._coordinate_descent.Elast...
# 3  sklearn.linear_model._coordinate_descent.Elast...
# 4  sklearn.linear_model._coordinate_descent.Elast...
# 5  sklearn.linear_model._coordinate_descent.Elast...
#
# [6 rows x 29 columns]

# %% [markdown]
# we can also obtain only the more interesting columns for our search

# %%
runs_metadata = mlflow.search_runs([experiment_id], order_by=["metrics.training_mse DESC"])
runs_metadata[['run_id', 'status', 'metrics.training_mse', 'metrics.training_r2_score']]
# Out:
#                              run_id    status  metrics.training_mse  \
# 0  c823e563d0c84de78b140f5fafc676cf  FINISHED              0.606808
# 1  49e52e988cd1436eb48d99104ae0d407  FINISHED              0.574932
# 2  1f5ab48a5cea4118ba8538268c5eb283  FINISHED              0.553625
# 3  dc299a55a6c74c9085fcdd9ca122b9d1  FINISHED              0.549027
# 4  e458c99ffadb4cb9a07b9274c2be7422  FINISHED              0.475265
# 5  d4c7e5ac674643e8bd37d69353109ace  FINISHED              0.474830
#
#    metrics.training_r2_score
# 0                   0.040883
# 1                   0.091266
# 2                   0.124943
# 3                   0.132211
# 4                   0.248799
# 5                   0.249486

# %% [markdown]
# If we have too many runs, we can filter them

# %%
# Search the experiment_id using a filter_string with tag
# that has a case insensitive pattern
filter_string = "metrics.training_mse > 0.55"
runs_metadata = mlflow.search_runs([experiment_id], filter_string=filter_string)
runs_metadata[['run_id', 'artifact_uri','status', 'metrics.training_mse', 'metrics.training_r2_score']]
# Out:
#                              run_id  \
# 0  49e52e988cd1436eb48d99104ae0d407
# 1  c823e563d0c84de78b140f5fafc676cf
# 2  1f5ab48a5cea4118ba8538268c5eb283
#
#                                         artifact_uri    status  \
# 0  s3://mlflow-bucket/mlflow/1/49e52e988cd1436eb4...  FINISHED
# 1  s3://mlflow-bucket/mlflow/1/c823e563d0c84de78b...  FINISHED
# 2  s3://mlflow-bucket/mlflow/1/1f5ab48a5cea4118ba...  FINISHED
#
#    metrics.training_mse  metrics.training_r2_score
# 0              0.574932                   0.091266
# 1              0.606808                   0.040883
# 2              0.553625                   0.124943

# %%
# best_artifact_uri = runs_metadata.sort_values(by='artifact_uri', ascending=False)
best_artifact_uri = runs_metadata.sort_values(by='metrics.training_mse', ascending=False)['artifact_uri'].values[0]
best_artifact_uri
# Out:
# 's3://mlflow-bucket/mlflow/1/c823e563d0c84de78b140f5fafc676cf/artifacts'

# %% [markdown]
# ## serving the model

# %% [markdown]
# Go to the terminal of your virtual machine where the MLflow server is running and execute the command to serve the model. This will deploy a local REST server that can serve predictions
#
# **command**: `mlflow models serve -m <artifact-uri> -p <port>`

# %% [markdown]
# ## Making predictions

# %% [markdown]
# To make a prediction using the deployed model, we can run the `curl` command on Linux:
#
# **command example**: `curl -X POST -H "Content-Type:application/json; format=pandas-split" --data '{"columns":["alcohol", "chlorides", "citric acid", "density", "fixed acidity", "free sulfur dioxide", "pH", "residual sugar", "sulphates", "total sulfur dioxide", "volatile acidity"],"data":[[12.8, 0.029, 0.48, 0.98, 6.2, 29, 3.33, 1.2, 0.39, 75, 0.66]]}' http://127.0.0.1:1234/invocations`

# %% [markdown]
# However, we can also use pure Python code to make predictions using the `request` library to make HTTP (POST) calls

# %%
# Read the wine-quality csv file from the URL
csv_url = (
    "http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
)
try:
    data = pd.read_csv(csv_url, sep=";")
except Exception as e:
    logger.exception(
        "Unable to download training & test CSV, check your internet connection. Error: %s", e
    )

# %%
# Split the data into training and test sets. (0.75, 0.25) split.
train, test = train_test_split(data)

# The predicted column is "quality" which is a scalar from [3, 9]
train_x = train.drop(["quality"], axis=1)
test_x = test.drop(["quality"], axis=1)
train_y = train[["quality"]]
test_y = test[["quality"]]

print('Train shape:', train_x.shape)
print('Train shape:', test_x.shape)
# Out:
# Train shape: (1199, 11)
# Train shape: (400, 11)

# %% [markdown]
# Take data from the downloaded dataset and take 1 or more rows to make the predictions. We will obtaine one prediction per row.
#
# Go to the official [documentation](https://mlflow.org/docs/latest/models.html#deploy-mlflow-models) for further details.

# %%
import requests

# %%
ip = 'localhost'
port = 1234

url = 'http://{0}:{1}/invocations'.format(ip, port)
test_x_json = test_x.to_json(orient='split')
test_x_json
# Out:
# '{"columns":["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcoh