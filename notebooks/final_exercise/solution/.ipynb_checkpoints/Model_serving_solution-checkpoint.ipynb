# %% [markdown]
# # Model Serving

# %% [markdown]
# This notebook contains the solution of the exercise where the best model of a concrete experiment must be deployed. In this example, we will use the already trained Random Forest models using the Data BankNote Authentication dataset from the UCI repository.
#
# This notebook contains the solution of the exercise where the best model of a concrete experiment must be registered in the MLflow Registry.

# %% [markdown]
# The first step is to import all the required libraries

# %%
import os
import warnings
import sys

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from urllib.parse import urlparse
import mlflow
import mlflow.sklearn
import boto3

import logging

logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)

warnings.filterwarnings("ignore")
np.random.seed(40)

# %% [markdown]
# Before registering a model in the MLflow Registry, it is recommended to search for the best model within all the runs and only register that one instead of registering every model.
#
# Once we have performed all the runs in an experiment, we can access the metadata of the experiment using its ID and the method ``search_runs`` provided by MLflow. Check the [documentation](https://www.mlflow.org/docs/latest/python_api/mlflow.html#mlflow.search_runs) for further details.
#
# Go to the MLflow UI and get the experiment ID of your choice.

# %%
# Search all runs in experiment_id
experiment_id = 9  # in this case experiment_id 9 = 'randomForest'
mlflow.search_runs([experiment_id])
# Out:
#                              run_id experiment_id    status  \
# 0  31271ea1c4a445b8813eafffc45e6d77             9  FINISHED
# 1  56379ac0c1a843b0b76a971c87ea82a4             9  FINISHED
# 2  5afee0e963204bcda8e068a905c9424b             9  FINISHED
# 3  2b0ab555e04041f9b8c5c40cf48adfa8             9  FINISHED
# 4  7284d63f4a784de88312d1e1639b544a             9  FINISHED
# 5  8d585dc6be574d10984f09b40f5ce805             9  FINISHED
# 6  94b86549a9ab4d91b5d5029f96f77221             9  FINISHED
# 7  4a93c8d907134ccea81d9838df4453eb             9  FINISHED
# 8  1287651cc0324d4495475a978ceed3dd             9  FINISHED
#
#                                         artifact_uri  \
# 0  s3://mlflow-bucket/mlflow/9/31271ea1c4a445b881...
# 1  s3://mlflow-bucket/mlflow/9/56379ac0c1a843b0b7...
# 2  s3://mlflow-bucket/mlflow/9/5afee0e963204bcda8...
# 3  s3://mlflow-bucket/mlflow/9/2b0ab555e04041f9b8...
# 4  s3://mlflow-bucket/mlflow/9/7284d63f4a784de883...
# 5  s3://mlflow-bucket/mlflow/9/8d585dc6be574d1098...
# 6  s3://mlflow-bucket/mlflow/9/94b86549a9ab4d91b5...
# 7  s3://mlflow-bucket/mlflow/9/4a93c8d907134ccea8...
# 8  s3://mlflow-bucket/mlflow/9/1287651cc0324d4495...
#
#                         start_time                         end_time  \
# 0 2020-12-10 10:41:33.580000+00:00 2020-12-10 10:41:34.699000+00:00
# 1 2020-12-10 10:41:32.329000+00:00 2020-12-10 10:41:33.559000+00:00
# 2 2020-12-10 10:41:30.970000+00:00 2020-12-10 10:41:32.313000+00:00
# 3 2020-12-10 10:41:29.809000+00:00 2020-12-10 10:41:30.915000+00:00
# 4 2020-12-10 10:41:28.917000+00:00 2020-12-10 10:41:29.790000+00:00
# 5 2020-12-10 10:41:28.151000+00:00 2020-12-10 10:41:28.896000+00:00
# 6 2020-12-10 10:41:27.552000+00:00 2020-12-10 10:41:28.134000+00:00
# 7 2020-12-10 10:41:26.976000+00:00 2020-12-10 10:41:27.527000+00:00
# 8 2020-12-10 10:41:26.274000+00:00 2020-12-10 10:41:26.954000+00:00
#
#    metrics.recall  metrics.accuracy  metrics.f1 params.n_estimators  \
# 0        0.979592          0.979592    0.979593                 300
# 1        0.973761          0.973761    0.973759                 300
# 2        0.938776          0.938776    0.938739                 300
# 3        0.976676          0.976676    0.976676                 200
# 4        0.973761          0.973761    0.973759                 200
# 5        0.935860          0.935860    0.935811                 200
# 6        0.973761          0.973761    0.973759                 100
# 7        0.973761          0.973761    0.973759                 100
# 8        0.938776          0.938776    0.938739                 100
#
#   params.max_depth                      tags.mlflow.log-model.history  \
# 0               10  [{"run_id": "31271ea1c4a445b8813eafffc45e6d77"...
# 1                6  [{"run_id": "56379ac0c1a843b0b76a971c87ea82a4"...
# 2                2  [{"run_id": "5afee0e963204bcda8e068a905c9424b"...
# 3               10  [{"run_id": "2b0ab555e04041f9b8c5c40cf48adfa8"...
# 4                6  [{"run_id": "7284d63f4a784de88312d1e1639b544a"...
# 5                2  [{"run_id": "8d585dc6be574d10984f09b40f5ce805"...
# 6               10  [{"run_id": "94b86549a9ab4d91b5d5029f96f77221"...
# 7                6  [{"run_id": "4a93c8d907134ccea81d9838df4453eb"...
# 8                2  [{"run_id": "1287651cc0324d4495475a978ceed3dd"...
#
#                              tags.mlflow.source.name tags.mlflow.source.type  \
# 0  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 1  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 2  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 3  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 4  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 5  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 6  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 7  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 8  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
#
#   tags.mlflow.user
# 0          mcanizo
# 1          mcanizo
# 2          mcanizo
# 3          mcanizo
# 4          mcanizo
# 5          mcanizo
# 6          mcanizo
# 7          mcanizo
# 8          mcanizo

# %% [markdown]
# Sort the metadata by the column corresponding to the metric of your choice. Select the one that is the most relevant to select the best model
#
# Hint: you can use the MLflow UI and the diferent plots provided when comparing multiple runs

# %%
mlflow.search_runs([experiment_id], order_by=["metrics.accuracy"])
# Out:
#                              run_id experiment_id    status  \
# 0  8d585dc6be574d10984f09b40f5ce805             9  FINISHED
# 1  5afee0e963204bcda8e068a905c9424b             9  FINISHED
# 2  1287651cc0324d4495475a978ceed3dd             9  FINISHED
# 3  56379ac0c1a843b0b76a971c87ea82a4             9  FINISHED
# 4  7284d63f4a784de88312d1e1639b544a             9  FINISHED
# 5  94b86549a9ab4d91b5d5029f96f77221             9  FINISHED
# 6  4a93c8d907134ccea81d9838df4453eb             9  FINISHED
# 7  2b0ab555e04041f9b8c5c40cf48adfa8             9  FINISHED
# 8  31271ea1c4a445b8813eafffc45e6d77             9  FINISHED
#
#                                         artifact_uri  \
# 0  s3://mlflow-bucket/mlflow/9/8d585dc6be574d1098...
# 1  s3://mlflow-bucket/mlflow/9/5afee0e963204bcda8...
# 2  s3://mlflow-bucket/mlflow/9/1287651cc0324d4495...
# 3  s3://mlflow-bucket/mlflow/9/56379ac0c1a843b0b7...
# 4  s3://mlflow-bucket/mlflow/9/7284d63f4a784de883...
# 5  s3://mlflow-bucket/mlflow/9/94b86549a9ab4d91b5...
# 6  s3://mlflow-bucket/mlflow/9/4a93c8d907134ccea8...
# 7  s3://mlflow-bucket/mlflow/9/2b0ab555e04041f9b8...
# 8  s3://mlflow-bucket/mlflow/9/31271ea1c4a445b881...
#
#                         start_time                         end_time  \
# 0 2020-12-10 10:41:28.151000+00:00 2020-12-10 10:41:28.896000+00:00
# 1 2020-12-10 10:41:30.970000+00:00 2020-12-10 10:41:32.313000+00:00
# 2 2020-12-10 10:41:26.274000+00:00 2020-12-10 10:41:26.954000+00:00
# 3 2020-12-10 10:41:32.329000+00:00 2020-12-10 10:41:33.559000+00:00
# 4 2020-12-10 10:41:28.917000+00:00 2020-12-10 10:41:29.790000+00:00
# 5 2020-12-10 10:41:27.552000+00:00 2020-12-10 10:41:28.134000+00:00
# 6 2020-12-10 10:41:26.976000+00:00 2020-12-10 10:41:27.527000+00:00
# 7 2020-12-10 10:41:29.809000+00:00 2020-12-10 10:41:30.915000+00:00
# 8 2020-12-10 10:41:33.580000+00:00 2020-12-10 10:41:34.699000+00:00
#
#    metrics.recall  metrics.accuracy  metrics.f1 params.n_estimators  \
# 0        0.935860          0.935860    0.935811                 200
# 1        0.938776          0.938776    0.938739                 300
# 2        0.938776          0.938776    0.938739                 100
# 3        0.973761          0.973761    0.973759                 300
# 4        0.973761          0.973761    0.973759                 200
# 5        0.973761          0.973761    0.973759                 100
# 6        0.973761          0.973761    0.973759                 100
# 7        0.976676          0.976676    0.976676                 200
# 8        0.979592          0.979592    0.979593                 300
#
#   params.max_depth                      tags.mlflow.log-model.history  \
# 0                2  [{"run_id": "8d585dc6be574d10984f09b40f5ce805"...
# 1                2  [{"run_id": "5afee0e963204bcda8e068a905c9424b"...
# 2                2  [{"run_id": "1287651cc0324d4495475a978ceed3dd"...
# 3                6  [{"run_id": "56379ac0c1a843b0b76a971c87ea82a4"...
# 4                6  [{"run_id": "7284d63f4a784de88312d1e1639b544a"...
# 5               10  [{"run_id": "94b86549a9ab4d91b5d5029f96f77221"...
# 6                6  [{"run_id": "4a93c8d907134ccea81d9838df4453eb"...
# 7               10  [{"run_id": "2b0ab555e04041f9b8c5c40cf48adfa8"...
# 8               10  [{"run_id": "31271ea1c4a445b8813eafffc45e6d77"...
#
#                              tags.mlflow.source.name tags.mlflow.source.type  \
# 0  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 1  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 2  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 3  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 4  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 5  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 6  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 7  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
# 8  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...                   LOCAL
#
#   tags.mlflow.user
# 0          mcanizo
# 1          mcanizo
# 2          mcanizo
# 3          mcanizo
# 4          mcanizo
# 5          mcanizo
# 6          mcanizo
# 7          mcanizo
# 8          mcanizo

# %% [markdown]
# Select only the most interesting columns to have a cleaner view of th emetadata

# %%
runs_metadata = mlflow.search_runs([experiment_id], order_by=["metrics.accuracy DESC"])
runs_metadata[['run_id', 'artifact_uri', 'status', 'metrics.accuracy', 'metrics.recall', 'metrics.f1']]
# Out:
#                              run_id  \
# 0  31271ea1c4a445b8813eafffc45e6d77
# 1  2b0ab555e04041f9b8c5c40cf48adfa8
# 2  56379ac0c1a843b0b76a971c87ea82a4
# 3  7284d63f4a784de88312d1e1639b544a
# 4  94b86549a9ab4d91b5d5029f96f77221
# 5  4a93c8d907134ccea81d9838df4453eb
# 6  5afee0e963204bcda8e068a905c9424b
# 7  1287651cc0324d4495475a978ceed3dd
# 8  8d585dc6be574d10984f09b40f5ce805
#
#                                         artifact_uri    status  \
# 0  s3://mlflow-bucket/mlflow/9/31271ea1c4a445b881...  FINISHED
# 1  s3://mlflow-bucket/mlflow/9/2b0ab555e04041f9b8...  FINISHED
# 2  s3://mlflow-bucket/mlflow/9/56379ac0c1a843b0b7...  FINISHED
# 3  s3://mlflow-bucket/mlflow/9/7284d63f4a784de883...  FINISHED
# 4  s3://mlflow-bucket/mlflow/9/94b86549a9ab4d91b5...  FINISHED
# 5  s3://mlflow-bucket/mlflow/9/4a93c8d907134ccea8...  FINISHED
# 6  s3://mlflow-bucket/mlflow/9/5afee0e963204bcda8...  FINISHED
# 7  s3://mlflow-bucket/mlflow/9/1287651cc0324d4495...  FINISHED
# 8  s3://mlflow-bucket/mlflow/9/8d585dc6be574d1098...  FINISHED
#
#    metrics.accuracy  metrics.recall  metrics.f1
# 0          0.979592        0.979592    0.979593
# 1          0.976676        0.976676    0.976676
# 2          0.973761        0.973761    0.973759
# 3          0.973761        0.973761    0.973759
# 4          0.973761        0.973761    0.973759
# 5          0.973761        0.973761    0.973759
# 6          0.938776        0.938776    0.938739
# 7          0.938776        0.938776    0.938739
# 8          0.935860        0.935860    0.935811

# %% [markdown]
# Filter runs that do not match a given condition

# %%
# Search the experiment_id using a filter_string with tag
# that has a case insensitive pattern
filter_string = "metrics.accuracy > 0.96"
runs_metadata = mlflow.search_runs([experiment_id], filter_string=filter_string)
runs_metadata[['run_id', 'artifact_uri', 'status', 'metrics.accuracy', 'metrics.recall', 'metrics.f1']]
# Out:
#                              run_id  \
# 0  31271ea1c4a445b8813eafffc45e6d77
# 1  56379ac0c1a843b0b76a971c87ea82a4
# 2  2b0ab555e04041f9b8c5c40cf48adfa8
# 3  7284d63f4a784de88312d1e1639b544a
# 4  94b86549a9ab4d91b5d5029f96f77221
# 5  4a93c8d907134ccea81d9838df4453eb
#
#                                         artifact_uri    status  \
# 0  s3://mlflow-bucket/mlflow/9/31271ea1c4a445b881...  FINISHED
# 1  s3://mlflow-bucket/mlflow/9/56379ac0c1a843b0b7...  FINISHED
# 2  s3://mlflow-bucket/mlflow/9/2b0ab555e04041f9b8...  FINISHED
# 3  s3://mlflow-bucket/mlflow/9/7284d63f4a784de883...  FINISHED
# 4  s3://mlflow-bucket/mlflow/9/94b86549a9ab4d91b5...  FINISHED
# 5  s3://mlflow-bucket/mlflow/9/4a93c8d907134ccea8...  FINISHED
#
#    metrics.accuracy  metrics.recall  metrics.f1
# 0          0.979592        0.979592    0.979593
# 1          0.973761        0.973761    0.973759
# 2          0.976676        0.976676    0.976676
# 3          0.973761        0.973761    0.973759
# 4          0.973761        0.973761    0.973759
# 5          0.973761        0.973761    0.973759

# %% [markdown]
# Get the artifact URI of the best model

# %%
# best_artifact_uri = runs_metadata.sort_values(by='artifact_uri', ascending=False)
best_artifact_uri = runs_metadata.sort_values(by='metrics.accuracy', ascending=False)['artifact_uri'].values[0]
best_artifact_uri
# Out:
# 's3://mlflow-bucket/mlflow/9/31271ea1c4a445b8813eafffc45e6d77/artifacts'

# %% [markdown]
# Register the best model into the MLflow registry

# %% [markdown]
# ## serving the model

# %% [markdown]
# Go to the terminal of your virtual machine where the MLflow server is running and execute the command to serve the model. This will deploy a local REST server that can serve predictions
#
# **command**: `mlflow models serve -m <artifact-uri> -p <port>`

# %% [markdown]
# ## Making predictions

# %% [markdown]
# To make a prediction using the deployed model, we can run the `curl` command on Linux:

# %% [markdown]
# However, we can also use pure Python code to make predictions using the `request` library to make HTTP (POST) calls

# %% [markdown]
# Download data_banknote_authentication Dataset from UCI repository

# %%
# Read the data_banknote_authentication.txt file from the URL
colnames=["variance", "skewness","curtosis","entropy", "class"]
data_url = (
    "https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt"
)

try:
    data = pd.read_csv(data_url, sep=",", header=None, names= colnames)
except Exception as e:
    logger.exception(
        "Unable to download training & test CSV, check your internet connection. Error: %s", e
    )

# %% [markdown]
# Split train/test datasets

# %%
# Split the data into training and test sets. (0.75, 0.25) split.
train, test = train_test_split(data)

train_x = train.drop(["class"], axis=1)
test_x = test.drop(["class"], axis=1)
train_y = train[["class"]]
test_y = test[["class"]]

print('Train shape:', train_x.shape)
print('Train shape:', test_x.shape)
# Out:
# Train shape: (1029, 4)
# Train shape: (343, 4)

# %% [markdown]
# Take data from the downloaded dataset and take 1 or more rows to make the predictions. We will obtaine one prediction per row.
#
# Go to the official [documentation](https://mlflow.org/docs/latest/models.html#deploy-mlflow-models) for further details.

# %% [markdown]
# import requests library

# %%
import requests

# %% [markdown]
# Get the url and the data that we will use to make predictions

# %%
ip = 'localhost'
port = 1234

url = 'http://{0}:{1}/invocations'.format(ip, port)
test_x_json = test_x.to_json(orient='split')
test_x_json

# %% [markdown]
# Do the HTTP

# %%
predictions = requests.post(
    url=url,
    data=test_x_json,
    headers={'Content-Type':'application/json; format=pandas-split'}
)

print('status code:', predictions.status_code)
print('predictions:\n', predictions.text)
