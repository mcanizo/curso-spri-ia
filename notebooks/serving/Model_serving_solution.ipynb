# %% [markdown]
# # Model Serving

# %% [markdown]
# This notebook contains the solution of the exercise where the best model of a concrete experiment must be deployed. In this example, we will use the already trained SVM models using the Iris dataset from the UCI repository.
#
# This notebook contains the solution of the exercise where the best model of a concrete experiment must be registered in the MLflow Registry.

# %% [markdown]
# The first step is to import all the required libraries

# %%
import os
import warnings
import sys

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from urllib.parse import urlparse
import mlflow
import mlflow.sklearn
import boto3

import logging

logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)

warnings.filterwarnings("ignore")
np.random.seed(40)

# %% [markdown]
# Before registering a model in the MLflow Registry, it is recommended to search for the best model within all the runs and only register that one instead of registering every model.
#
# Once we have performed all the runs in an experiment, we can access the metadata of the experiment using its ID and the method ``search_runs`` provided by MLflow. Check the [documentation](https://www.mlflow.org/docs/latest/python_api/mlflow.html#mlflow.search_runs) for further details.
#
# Go to the MLflow UI and get the experiment ID of your choice.

# %%
# Search all runs in experiment_id
experiment_id = 4  # in this case experiment_id 4 = 'iris_gridsearch'
mlflow.search_runs([experiment_id])
# Out:
#                               run_id experiment_id    status  \
# 0   37f94a7a414c4ac983c12a9a1aa1613c             4  FINISHED
# 1   e9d212f6c6334232ba87d64284e2167c             4  FINISHED
# 2   e2d04069c2c6416283f05036acc35234             4  FINISHED
# 3   de1803bac63f44e3a0ac242629218eed             4  FINISHED
# 4   6478189caa474d2faf6d45b0556a54ba             4  FINISHED
# 5   70a0a00e67c74d17b8e0a4a58572d103             4  FINISHED
# 6   ca3ada1abe9d46dd850eb30ffce94de2             4  FINISHED
# 7   3e5ca9dfbd534ce5abb79d0b8c31a836             4  FINISHED
# 8   9c1c718524784d1882337358dd5b03a0             4  FINISHED
# 9   e9d93fea98d945528e2b5c3337010785             4  FINISHED
# 10  531757563d794e63953082b255839f24             4  FINISHED
# 11  7426c3cca6014f9ebbfe8b4b86467ac7             4  FINISHED
# 12  dba8573569ef44a8942c9105d3f5bf1a             4  FINISHED
# 13  9726da2c7fbd4466acef5fba09cfda95             4  FINISHED
# 14  58d04d8e510142aab25e115dd08f28cb             4  FINISHED
#
#                                          artifact_uri  \
# 0   s3://mlflow-bucket/mlflow/4/37f94a7a414c4ac983...
# 1   s3://mlflow-bucket/mlflow/4/e9d212f6c6334232ba...
# 2   s3://mlflow-bucket/mlflow/4/e2d04069c2c6416283...
# 3   s3://mlflow-bucket/mlflow/4/de1803bac63f44e3a0...
# 4   s3://mlflow-bucket/mlflow/4/6478189caa474d2faf...
# 5   s3://mlflow-bucket/mlflow/4/70a0a00e67c74d17b8...
# 6   s3://mlflow-bucket/mlflow/4/ca3ada1abe9d46dd85...
# 7   s3://mlflow-bucket/mlflow/4/3e5ca9dfbd534ce5ab...
# 8   s3://mlflow-bucket/mlflow/4/9c1c718524784d1882...
# 9   s3://mlflow-bucket/mlflow/4/e9d93fea98d945528e...
# 10  s3://mlflow-bucket/mlflow/4/531757563d794e6395...
# 5           mcanizo  [{"run_id": "70a0a00e67c74d17b8e0a4a58572d103"...
# 6           mcanizo  [{"run_id": "ca3ada1abe9d46dd850eb30ffce94de2"...
# 7           mcanizo  [{"run_id": "3e5ca9dfbd534ce5abb79d0b8c31a836"...
# 8           mcanizo  [{"run_id": "9c1c718524784d1882337358dd5b03a0"...
# 9           mcanizo  [{"run_id": "e9d93fea98d945528e2b5c3337010785"...
# 10          mcanizo  [{"run_id": "531757563d794e63953082b255839f24"...
# 11          mcanizo  [{"run_id": "7426c3cca6014f9ebbfe8b4b86467ac7"...
# 12          mcanizo  [{"run_id": "dba8573569ef44a8942c9105d3f5bf1a"...
# 13          mcanizo  [{"run_id": "9726da2c7fbd4466acef5fba09cfda95"...
# 14          mcanizo  [{"run_id": "58d04d8e510142aab25e115dd08f28cb"...
#
#    tags.mlflow.source.type                            tags.mlflow.source.name
# 0                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 1                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 2                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 3                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 4                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 5                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 6                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 7                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 8                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 9                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 10                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 11                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 12                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 13                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 14                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...

# %% [markdown]
# Sort the metadata by the column corresponding to the metric of your choice. Select the one that is the most relevant to select the best model
#
# Hint: you can use the MLflow UI and the diferent plots provided when comparing multiple runs

# %%
mlflow.search_runs([experiment_id], order_by=["metrics.accuracy"])
# Out:
#                               run_id experiment_id    status  \
# 0   6478189caa474d2faf6d45b0556a54ba             4  FINISHED
# 1   e2d04069c2c6416283f05036acc35234             4  FINISHED
# 2   37f94a7a414c4ac983c12a9a1aa1613c             4  FINISHED
# 3   e9d212f6c6334232ba87d64284e2167c             4  FINISHED
# 4   de1803bac63f44e3a0ac242629218eed             4  FINISHED
# 5   e9d93fea98d945528e2b5c3337010785             4  FINISHED
# 6   70a0a00e67c74d17b8e0a4a58572d103             4  FINISHED
# 7   ca3ada1abe9d46dd850eb30ffce94de2             4  FINISHED
# 8   3e5ca9dfbd534ce5abb79d0b8c31a836             4  FINISHED
# 9   531757563d794e63953082b255839f24             4  FINISHED
# 10  7426c3cca6014f9ebbfe8b4b86467ac7             4  FINISHED
# 11  dba8573569ef44a8942c9105d3f5bf1a             4  FINISHED
# 12  58d04d8e510142aab25e115dd08f28cb             4  FINISHED
# 13  9c1c718524784d1882337358dd5b03a0             4  FINISHED
# 14  9726da2c7fbd4466acef5fba09cfda95             4  FINISHED
#
#                                          artifact_uri  \
# 0   s3://mlflow-bucket/mlflow/4/6478189caa474d2faf...
# 1   s3://mlflow-bucket/mlflow/4/e2d04069c2c6416283...
# 2   s3://mlflow-bucket/mlflow/4/37f94a7a414c4ac983...
# 3   s3://mlflow-bucket/mlflow/4/e9d212f6c6334232ba...
# 4   s3://mlflow-bucket/mlflow/4/de1803bac63f44e3a0...
# 5   s3://mlflow-bucket/mlflow/4/e9d93fea98d945528e...
# 6   s3://mlflow-bucket/mlflow/4/70a0a00e67c74d17b8...
# 7   s3://mlflow-bucket/mlflow/4/ca3ada1abe9d46dd85...
# 2           mcanizo  [{"run_id": "37f94a7a414c4ac983c12a9a1aa1613c"...
# 3           mcanizo  [{"run_id": "e9d212f6c6334232ba87d64284e2167c"...
# 4           mcanizo  [{"run_id": "de1803bac63f44e3a0ac242629218eed"...
# 5           mcanizo  [{"run_id": "e9d93fea98d945528e2b5c3337010785"...
# 6           mcanizo  [{"run_id": "70a0a00e67c74d17b8e0a4a58572d103"...
# 7           mcanizo  [{"run_id": "ca3ada1abe9d46dd850eb30ffce94de2"...
# 8           mcanizo  [{"run_id": "3e5ca9dfbd534ce5abb79d0b8c31a836"...
# 9           mcanizo  [{"run_id": "531757563d794e63953082b255839f24"...
# 10          mcanizo  [{"run_id": "7426c3cca6014f9ebbfe8b4b86467ac7"...
# 11          mcanizo  [{"run_id": "dba8573569ef44a8942c9105d3f5bf1a"...
# 12          mcanizo  [{"run_id": "58d04d8e510142aab25e115dd08f28cb"...
# 13          mcanizo  [{"run_id": "9c1c718524784d1882337358dd5b03a0"...
# 14          mcanizo  [{"run_id": "9726da2c7fbd4466acef5fba09cfda95"...
#
#    tags.mlflow.source.type                            tags.mlflow.source.name
# 0                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 1                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 2                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 3                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 4                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 5                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 6                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 7                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 8                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 9                    LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 10                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 11                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 12                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 13                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...
# 14                   LOCAL  /home/mcanizo/anaconda3/envs/mlflowEnv/lib/pyt...

# %% [markdown]
# Select only the most interesting columns to have a cleaner view of th emetadata

# %%
runs_metadata = mlflow.search_runs([experiment_id], order_by=["metrics.accuracy DESC"])
runs_metadata[['run_id', 'artifact_uri', 'status', 'metrics.accuracy', 'metrics.recall', 'metrics.f1']]
# Out:
#                               run_id  \
# 0   9c1c718524784d1882337358dd5b03a0
# 1   9726da2c7fbd4466acef5fba09cfda95
# 2   70a0a00e67c74d17b8e0a4a58572d103
# 3   ca3ada1abe9d46dd850eb30ffce94de2
# 4   3e5ca9dfbd534ce5abb79d0b8c31a836
# 5   531757563d794e63953082b255839f24
# 6   7426c3cca6014f9ebbfe8b4b86467ac7
# 7   dba8573569ef44a8942c9105d3f5bf1a
# 8   58d04d8e510142aab25e115dd08f28cb
# 9   37f94a7a414c4ac983c12a9a1aa1613c
# 10  e9d212f6c6334232ba87d64284e2167c
# 11  de1803bac63f44e3a0ac242629218eed
# 12  e9d93fea98d945528e2b5c3337010785
# 13  e2d04069c2c6416283f05036acc35234
# 14  6478189caa474d2faf6d45b0556a54ba
#
#                                          artifact_uri    status  \
# 0   s3://mlflow-bucket/mlflow/4/9c1c718524784d1882...  FINISHED
# 1   s3://mlflow-bucket/mlflow/4/9726da2c7fbd4466ac...  FINISHED
# 2   s3://mlflow-bucket/mlflow/4/70a0a00e67c74d17b8...  FINISHED
# 3   s3://mlflow-bucket/mlflow/4/ca3ada1abe9d46dd85...  FINISHED
# 4   s3://mlflow-bucket/mlflow/4/3e5ca9dfbd534ce5ab...  FINISHED
# 5   s3://mlflow-bucket/mlflow/4/531757563d794e6395...  FINISHED
# 6   s3://mlflow-bucket/mlflow/4/7426c3cca6014f9ebb...  FINISHED
# 7   s3://mlflow-bucket/mlflow/4/dba8573569ef44a894...  FINISHED
# 8   s3://mlflow-bucket/mlflow/4/58d04d8e510142aab2...  FINISHED
# 9   s3://mlflow-bucket/mlflow/4/37f94a7a414c4ac983...  FINISHED
# 10  s3://mlflow-bucket/mlflow/4/e9d212f6c6334232ba...  FINISHED
# 11  s3://mlflow-bucket/mlflow/4/de1803bac63f44e3a0...  FINISHED
# 12  s3://mlflow-bucket/mlflow/4/e9d93fea98d945528e...  FINISHED
# 13  s3://mlflow-bucket/mlflow/4/e2d04069c2c6416283...  FINISHED
# 14  s3://mlflow-bucket/mlflow/4/6478189caa474d2faf...  FINISHED
#
#     metrics.accuracy  metrics.recall  metrics.f1
# 0           1.000000        1.000000    1.000000
# 1           1.000000        1.000000    1.000000
# 2           0.973684        0.973684    0.973364
# 3           0.973684        0.973684    0.973364
# 4           0.973684        0.973684    0.973364
# 5           0.973684        0.973684    0.973364
# 6           0.973684        0.973684    0.973889
# 7           0.973684        0.973684    0.973889
# 8           0.973684        0.973684    0.973889
# 9           0.947368        0.947368    0.947976
# 10          0.947368        0.947368    0.947976
# 11          0.947368        0.947368    0.947976
# 12          0.947368        0.947368    0.947976
# 13          0.921053        0.921053    0.921955
# 14          0.894737        0.894737    0.895534

# %% [markdown]
# Filter runs that do not match a given condition

# %%
# Search the experiment_id using a filter_string with tag
# that has a case insensitive pattern
filter_string = "metrics.accuracy > 0.96"
runs_metadata = mlflow.search_runs([experiment_id], filter_string=filter_string)
runs_metadata[['run_id', 'artifact_uri', 'status', 'metrics.accuracy', 'metrics.recall', 'metrics.f1']]
# Out:
#                              run_id  \
# 0  70a0a00e67c74d17b8e0a4a58572d103
# 1  ca3ada1abe9d46dd850eb30ffce94de2
# 2  3e5ca9dfbd534ce5abb79d0b8c31a836
# 3  9c1c718524784d1882337358dd5b03a0
# 4  531757563d794e63953082b255839f24
# 5  7426c3cca6014f9ebbfe8b4b86467ac7
# 6  dba8573569ef44a8942c9105d3f5bf1a
# 7  9726da2c7fbd4466acef5fba09cfda95
# 8  58d04d8e510142aab25e115dd08f28cb
#
#                                         artifact_uri    status  \
# 0  s3://mlflow-bucket/mlflow/4/70a0a00e67c74d17b8...  FINISHED
# 1  s3://mlflow-bucket/mlflow/4/ca3ada1abe9d46dd85...  FINISHED
# 2  s3://mlflow-bucket/mlflow/4/3e5ca9dfbd534ce5ab...  FINISHED
# 3  s3://mlflow-bucket/mlflow/4/9c1c718524784d1882...  FINISHED
# 4  s3://mlflow-bucket/mlflow/4/531757563d794e6395...  FINISHED
# 5  s3://mlflow-bucket/mlflow/4/7426c3cca6014f9ebb...  FINISHED
# 6  s3://mlflow-bucket/mlflow/4/dba8573569ef44a894...  FINISHED
# 7  s3://mlflow-bucket/mlflow/4/9726da2c7fbd4466ac...  FINISHED
# 8  s3://mlflow-bucket/mlflow/4/58d04d8e510142aab2...  FINISHED
#
#    metrics.accuracy  metrics.recall  metrics.f1
# 0          0.973684        0.973684    0.973364
# 1          0.973684        0.973684    0.973364
# 2          0.973684        0.973684    0.973364
# 3          1.000000        1.000000    1.000000
# 4          0.973684        0.973684    0.973364
# 5          0.973684        0.973684    0.973889
# 6          0.973684        0.973684    0.973889
# 7          1.000000        1.000000    1.000000
# 8          0.973684        0.973684    0.973889

# %% [markdown]
# Get the artifact URI of the best model

# %%
# best_artifact_uri = runs_metadata.sort_values(by='artifact_uri', ascending=False)
best_artifact_uri = runs_metadata.sort_values(by='metrics.accuracy', ascending=False)['artifact_uri'].values[0]
best_artifact_uri
# Out:
# 's3://mlflow-bucket/mlflow/4/9c1c718524784d1882337358dd5b03a0/artifacts'

# %% [markdown]
# Register the best model into the MLflow registry

# %% [markdown]
# ## serving the model

# %% [markdown]
# Go to the terminal of your virtual machine where the MLflow server is running and execute the command to serve the model. This will deploy a local REST server that can serve predictions
#
# **command**: `mlflow models serve -m <artifact-uri> -p <port>`

# %% [markdown]
# ## Making predictions

# %% [markdown]
# To make a prediction using the deployed model, we can run the `curl` command on Linux:

# %% [markdown]
# However, we can also use pure Python code to make predictions using the `request` library to make HTTP (POST) calls

# %% [markdown]
# Download Iris Dataset from UCI repository

# %%
# Read the iris .data file from the URL
colnames=["sepal_length_in_cm", "sepal_width_in_cm","petal_length_in_cm","petal_width_in_cm", "class"]
data_url = (
    "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
)

try:
    data = pd.read_csv(data_url, sep=",", header=None, names= colnames)
except Exception as e:
    logger.exception(
        "Unable to download training & test CSV, check your internet connection. Error: %s", e
    )

# %% [markdown]
# Split train/test datasets

# %%
# Split the data into training and test sets. (0.75, 0.25) split.
train, test = train_test_split(data)

train_x = train.drop(["class"], axis=1)
test_x = test.drop(["class"], axis=1)
train_y = train[["class"]]
test_y = test[["class"]]

print('Train shape:', train_x.shape)
print('Train shape:', test_x.shape)
# Out:
# Train shape: (112, 4)
# Train shape: (38, 4)

# %% [markdown]
# Take data from the downloaded dataset and take 1 or more rows to make the predictions. We will obtaine one prediction per row.
#
# Go to the official [documentation](https://mlflow.org/docs/latest/models.html#deploy-mlflow-models) for further details.

# %% [markdown]
# import requests library

# %%
import requests

# %% [markdown]
# Get the url and the data that we will use to make predictions

# %%
ip = 'localhost'
port = 1234

url = 'http://{0}:{1}/invocations'.format(ip, port)
test_x_json = test_x.to_json(orient='split')
test_x_json

# %% [markdown]
# Do the HTTP

# %%
predictions = requests.post(
    url=url,
    data=test_x_json,
    headers={'Content-Type':'application/json; format=pandas-split'}
)

print('status code:', predictions.status_code)
print('predictions:\n', predictions.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c3f2531ed90b> in <module>
#       1 predictions = requests.post(
# ----> 2     url=url,
#       3     data=test_x_json,
#       4     headers={'Content-Type':'application/json; format=pandas-split'}
#       5 )
#
# NameError: name 'url' is not defined
